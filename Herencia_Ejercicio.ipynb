# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisAntonioGI13/Python-Curse/blob/main/Herencia_Ejercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Vehiculo():

    def __init__(self, color, ruedas):
        self.color = color
        self.ruedas = ruedas

    def __str__(self):
        return "Color {}, {} ruedas".format( self.color, self.ruedas )

class Coche(Vehiculo):

    def __init__(self, color, ruedas, velocidad, cilindrada):
        self.color = color
        self.ruedas = ruedas
        self.velocidad = velocidad
        self.cilindrada = cilindrada

    def __str__(self):
        return "color {}, {} km/h, {} ruedas, {} cc".format( self.color, self.velocidad, self.ruedas, self.cilindrada )


coche = Coche("azul", 4, 150, 1200)
print(coche)
# Out:
# color azul, 150 km/h, 4 ruedas, 1200 cc

# %% [markdown]
# ![EjercicioClases.png](data:image/png;base64,...)

# %% [markdown]
# * Crea al menos un objeto de cada subclase y añádelos a una lista llamada vehiculos.
#
# * Realiza una función llamada catalogar() que reciba la lista de vehiculos y los recorra mostrando el nombre de su clase y sus atributos.
#
# * Modifica la función catalogar() para que reciba un argumento optativo ruedas, haciendo que muestre únicamente los que su número de ruedas concuerde con el valor del argumento. También debe mostrar un mensaje "Se han encontrado {} vehículos con {} ruedas:" únicamente si se envía el argumento ruedas. Ponla a prueba con 0, 2 y 4 ruedas como valor.

# %%
class Vehiculo():

    def __init__(self, color, ruedas):
        self.color = color
        self.ruedas = ruedas

    def __str__(self):
        return "color {}, {} ruedas".format( self.color, self.ruedas )


class Coche(Vehiculo):

    def __init__(self, color, ruedas, velocidad, cilindrada):
        Vehiculo.__init__(self, color, ruedas)
        self.velocidad = velocidad
        self.cilindrada = cilindrada

    def __str__(self):
        return Vehiculo.__str__(self) + ", {} km/h, {} cc".format(self.velocidad, self.cilindrada)


c = Coche("azul", 4, 150, 1200)
print(c)

v = Vehiculo("Rojo", 2)
print(v)
# Out:
# color azul, 4 ruedas, 150 km/h, 1200 cc
# color Rojo, 2 ruedas

# %%
class Vehiculo():

    def __init__(self, color, ruedas):
        self.color = color
        self.ruedas = ruedas

    def __str__(self):
        return "color {}, {} ruedas".format( self.color, self.ruedas )


class Coche(Vehiculo):

    def __init__(self, color, ruedas, velocidad, cilindrada):
        super().__init__(color, ruedas)
        self.velocidad = velocidad
        self.cilindrada = cilindrada

    def __str__(self):
        return super().__str__() + ", {} km/h, {} cc".format(self.velocidad, self.cilindrada)


class Camioneta(Coche):

  def __init__(self, color, ruedas, velocidad, cilindrada, carga):
    super().__init__(color, ruedas, velocidad, cilindrada)
    self.carga = carga

  def __str__(self):
      return super().__str__() + ", {} Kg".format(self.carga)


class Bicicleta(Vehiculo):

  def __init__(self, color, ruedas, tipo):
      super().__init__(color, ruedas)
      self.tipo = tipo


  def __str__(self):
    return super().__str__() + ", Tipo: {}".format(self.tipo)



class Motocicleta(Bicicleta):

  def __init__(self, color, ruedas, tipo, velocidad, cilindrada):
    super().__init__(color, ruedas, tipo)
    self.velocidad = velocidad
    self.cilindrada = cilindrada

  def __str__(self):
    return super().__str__() + ", {} km/h, {} cc".format(self.velocidad, self.cilindrada)


c = Coche("azul", 4, 150, 1200)
print(c)

cam = Camioneta("azul", 4, 150, 1200, 2000)
print(cam)

bi = Bicicleta("rojo", 2,"Urbana")
print(bi)

mot = Motocicleta("negra", 2,"Deportiva", 150, 800)
print(mot)
# Out:
# <class '__main__.Coche'>
#
# <class '__main__.Camioneta'>
#
# <class '__main__.Bicicleta'>
#
# <class '__main__.Motocicleta'>
#
# color azul, 4 ruedas, 150 km/h, 1200 cc
# color azul, 4 ruedas, 150 km/h, 1200 cc, 2000 Kg
# color rojo, 2 ruedas, Tipo: Urbana
# color negra, 2 ruedas, Tipo: Deportiva, 150 km/h, 800 cc

# %%
vehiculos = [

  Coche("azul", 4, 150, 1200),
  Camioneta("azul", 4, 150, 1200, 2000),
  Bicicleta("rojo", 2,"Urbana"),
  Motocicleta("negra", 2,"Deportiva", 150, 800)

]

for i in vehiculos:
  print(i, "\n")
# Out:
# color azul, 4 ruedas, 150 km/h, 1200 cc
#
# color azul, 4 ruedas, 150 km/h, 1200 cc, 2000 Kg
#
# color rojo, 2 ruedas, Tipo: Urbana
#
# color negra, 2 ruedas, Tipo: Deportiva, 150 km/h, 800 cc

# %%
#def catalogar(lista):

#  for i in lista:
#    print("{} {}".format(type(i).__name__ , i))

# %%
catalogar(vehiculos)
# Out:
# Coche color azul, 4 ruedas, 150 km/h, 1200 cc
# Camioneta color azul, 4 ruedas, 150 km/h, 1200 cc, 2000 Kg
# Bicicleta color rojo, 2 ruedas, Tipo: Urbana
# Motocicleta color negra, 2 ruedas, Tipo: Deportiva, 150 km/h, 800 cc

# %%
def catalogar2(lista, ruedas = None):
   if ruedas != None:
    contador = 0
    for i in vehiculos:
      if i.ruedas == ruedas:
        contador += 1
    print("Se han encontrado {} vehículos con {} ruedas".format(contador, ruedas))


    for i in lista:
      if i.ruedas == None:
        print("{} {}".format(type(i).__name__ , i))

      else :
        if i.ruedas == ruedas:
          print("{} {}".format(type(i).__name__ , i))

# %%
catalogar2(vehiculos, 4)
# Out:
# Se han encontrado 2 vehículos con 4 ruedas
# Coche color azul, 4 ruedas, 150 km/h, 1200 cc
# Camioneta color azul, 4 ruedas, 150 km/h, 1200 cc, 2000 Kg
